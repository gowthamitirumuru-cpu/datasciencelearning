# %% [markdown]
# <a href="https://colab.research.google.com/github/gowthamitirumuru-cpu/datasciencelearning/blob/main/biverate_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv("/Dataset.csv")
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
print(df.columns)
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns.tolist())
# Out:
# ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status']

# %%
df.columns = df.columns.str.strip()

# %%
pd.crosstab(df['Gender'], df['Loan_Status'])
# Out:
# Loan_Status    N    Y
# Gender
# Female        37   75
# Male         150  339

# %%
sns.countplot(x='Gender', hue='Loan_Status', data=df)
plt.title("Gender vs Loan Status")
plt.show()

# %% [markdown]
# Gender vs Loan Status: Male and Female applicants' loan approval distribution was analyzed.

# %%
sns.countplot(x='Married', hue='Loan_Status', data=df)
plt.title("Married vs Loan Status")
plt.show()

# %% [markdown]
# Married vs Loan Status: Loan approval varies based on marital status.

# %%
sns.countplot(x='Education', hue='Loan_Status', data=df)
plt.title("Education vs Loan Status")
plt.show()

# %% [markdown]
# Education vs Loan Status: Education level has some impact on loan approval.

# %%
sns.countplot(x='Credit_History', hue='Loan_Status', data=df)
plt.title("Credit History vs Loan Status")
plt.show()

# %% [markdown]
# Credit History vs Loan Status: Applicants with a good credit history have a higher chance of loan approval.

# %%
sns.scatterplot(x='ApplicantIncome', y='LoanAmount', data=df)
plt.title("Applicant Income vs Loan Amount")
plt.show()

# %% [markdown]
# Applicant Income vs Loan Amount: Higher applicant income generally corresponds to higher loan amounts.
